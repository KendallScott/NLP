# %% [markdown]
# Homework 4
#
# 1.	Run one of the part-of-speech (POS) taggers available in Python.
# a.	Find the longest sentence you can, longer than 10 words, that the POS tagger tags correctly. Show the input and output.
# b.	Find the shortest sentence you can, shorter than 10 words, that the POS tagger fails to tag 100 percent correctly. Show the input and output. Explain your conjecture as to why the tagger might have been less than perfect with this sentence.

# %%
import nltk
nltk.download('punkt')
nltk.download('averaged_perceptron_tagger')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# True

# %%
import nltk
from nltk.stem import PorterStemmer
from gensim.parsing.preprocessing import remove_stopwords
from nltk.stem.wordnet import WordNetLemmatizer
from nltk.stem import WordNetLemmatizer
import nltk
nltk.download('wordnet')
nltk.download("punkt")
from nltk import word_tokenize
nltk.download('universal_tagset')
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!
# True

# %%
gone_w_the_wind = "Scarlett O'Hara was not beautiful, but men seldom realized it when caught by her charm as the Tarleton twins were."
tokens = word_tokenize(gone_w_the_wind)
gone_w_the_wind_tags = nltk.pos_tag(tokens, tagset = "universal")

# %%
gone_w_the_wind_tags
# Out:
# [('Scarlett', 'NOUN'),
#  ("O'Hara", 'NOUN'),
#  ('was', 'VERB'),
#  ('not', 'ADV'),
#  ('beautiful', 'ADJ'),
#  (',', '.'),
#  ('but', 'CONJ'),
#  ('men', 'NOUN'),
#  ('seldom', 'ADV'),
#  ('realized', 'VERB'),
#  ('it', 'PRON'),
#  ('when', 'ADV'),
#  ('caught', 'VERB'),
#  ('by', 'ADP'),
#  ('her', 'PRON'),
#  ('charm', 'NOUN'),
#  ('as', 'ADP'),
#  ('the', 'DET'),
#  ('Tarleton', 'NOUN'),
#  ('twins', 'NOUN'),
#  ('were', 'VERB'),
#  ('.', '.')]

# %% [markdown]
# The tagger accurately tagged all of the starting sentence of the book Gone with the Wind, which is a 20 word sentence. The sentence is complex, but communicating in a way that is unambiguous, which is why I believe the tagger was able to accurately label each word.

# %%
rumi = "If the light is in your heart, you will find your way home."
tokens = word_tokenize(rumi)
rumi_tags = nltk.pos_tag(tokens, tagset = "universal")

# %%
rumi_tags
# Out:
# [('If', 'ADP'),
#  ('the', 'DET'),
#  ('light', 'NOUN'),
#  ('is', 'VERB'),
#  ('in', 'ADP'),
#  ('your', 'PRON'),
#  ('heart', 'NOUN'),
#  (',', '.'),
#  ('you', 'PRON'),
#  ('will', 'VERB'),
#  ('find', 'VERB'),
#  ('your', 'PRON'),
#  ('way', 'NOUN'),
#  ('home', 'NOUN'),
#  ('.', '.')]

# %% [markdown]
# In the Rumi quote, the tagger miscategorized light as a noun, when in this quote it is being used as a adjective or verb. This is because spiritual language is often used in ways that aren't concrete or literal, as Rumi often breaks the rules of english grammar to make a point.

# %% [markdown]
# 2.	Run a different POS tagger in Python. Process the same two sentences from question 1.
# a.	Does it produce the same or different output?
# b.	Explain any differences as best you can.

# %%
import spacy
sp = spacy.load('en_core_web_sm')

# %%
sen = sp(gone_w_the_wind)
i=0
for word in sen:
    print(f'{word.text:{i}} {word.pos_:{i}}')
    i+=1
# Out:
# Scarlett PROPN
# O'Hara PROPN
# was AUX
# not PART
# beautiful ADJ
# ,     PUNCT
# but    CCONJ
# men     NOUN
# seldom   ADV
# realized  VERB
# it         PRON
# when        SCONJ
# caught       VERB
# by            ADP
# her            PRON
# charm           NOUN
# as               SCONJ
# the               DET
# Tarleton           PROPN
# twins               NOUN
# were                 AUX
# .                     PUNCT

# %% [markdown]
# While the initial pos_tagger using nltk looked to be accurate, the results from spacy library were more specific in capturing proper nouns.

# %%
sen = sp(rumi)
i=0
for word in sen:
    print(f'{word.text:{i}} {word.pos_:{i}}')
    i+=1
# Out:
# If SCONJ
# the DET
# light NOUN
# is  AUX
# in   ADP
# your  PRON
# heart  NOUN
# ,       PUNCT
# you      PRON
# will      AUX
# find       VERB
# your        PRON
# way          NOUN
# home          ADV
# .              PUNCT

# %% [markdown]
# The miscategorization of light in the Rumi quote happened again using the spacy library. Although it would be difficult to say how light is being used, as it could be categorized as either a verb, adjective or adverb in this context, depending on how you interpreted the quote.

# %% [markdown]
# 3.	In a news article from this week’s news, find a random sentence of at least 10 words.
# a.	Looking at the Penn tag set, manually POS tag the sentence yourself.
# b.	Now run the same sentences through both taggers that you implemented for questions 1 and 2. Did either of the taggers produce the same results as you had created manually?
# c.	Explain any differences between the two taggers and your manual tagging as much as you can.

# %%
news="In the year since the U.S. Supreme Court reversed Roe v. Wade, 14 states have banned most abortions, but even more have moved to protect abortion rights in various ways."

# %% [markdown]
# *   In = adposition
# *   the =determiner
# *   year =noun
# *   since =preposition
# *   the =determiner
# *   U.S. = noun
# *   Supreme = noun
# *   Court = noun
# *   reversed =veb
# *   Roe v. Wade = noun
# *   14 = number
# *   states =noun
# *   have = verb
# *   banned  = verb
# *   most = adjective
# *   abortions = noun
# *   but =conjunction
# *   even = adverb
# *   more = adjective
# *   have  = verb
# *   moved = verb
# *   to = particle
# *   protect = verb
# *   abortion =noun
# *   rights = noun
# *   in = adposition
# *   various = adjective
# *   ways = noun

# %%
tokens = word_tokenize(news)
news_tags = nltk.pos_tag(tokens, tagset = "universal")
news_tags
# Out:
# [('In', 'ADP'),
#  ('the', 'DET'),
#  ('year', 'NOUN'),
#  ('since', 'ADP'),
#  ('the', 'DET'),
#  ('U.S.', 'NOUN'),
#  ('Supreme', 'NOUN'),
#  ('Court', 'NOUN'),
#  ('reversed', 'VERB'),
#  ('Roe', 'NOUN'),
#  ('v.', 'X'),
#  ('Wade', 'NOUN'),
#  (',', '.'),
#  ('14', 'NUM'),
#  ('states', 'NOUN'),
#  ('have', 'VERB'),
#  ('banned', 'VERB'),
#  ('most', 'ADJ'),
#  ('abortions', 'NOUN'),
#  (',', '.'),
#  ('but', 'CONJ'),
#  ('even', 'ADV'),
#  ('more', 'ADJ'),
#  ('have', 'VERB'),
#  ('moved', 'VERB'),
#  ('to', 'PRT'),
#  ('protect', 'VERB'),
#  ('abortion', 'NOUN'),
#  ('rights', 'NOUN'),
#  ('in', 'ADP'),
#  ('various', 'ADJ'),
#  ('ways', 'NOUN'),
#  ('.', '.')]

# %%
sen = sp(news)
i=0
for word in sen:
    print(f'{word.text:{i}} {word.pos_:{i}}')
    i+=1
# Out:
# In ADP
# the DET
# year NOUN
# since SCONJ
# the  DET
# U.S.  PROPN
# Supreme PROPN
# Court   PROPN
# reversed VERB
# Roe       PROPN
# v.         ADP
# Wade        PROPN
# ,            PUNCT
# 14            NUM
# states         NOUN
# have            AUX
# banned           VERB
# most              ADJ
# abortions          NOUN
# ,                   PUNCT
# but                  CCONJ
# even                  ADV
# more                   ADV
# have                    AUX
# moved                    VERB
# to                        PART
# protect                    VERB
# abortion                    NOUN
# rights                       NOUN
# in                            ADP
# various                        ADJ
# ways                            NOUN
# .                                PUNCT

# %% [markdown]
# The pos taggers categorized the sentence on abortion rights in the same ways that I did, with the exception of the spacy library, which categorized proper nouns and the v. portion of the sentence, which I skipped.
